# %%
# Load 5-year CP5 dataset
df = spark.read.parquet("dbfs:/student-groups/Group_4_4/checkpoint_5_final_clean_2015-2019.parquet")

print("Rows:", df.count())
print("Columns:", len(df.columns))
df.printSchema()
# Out:
# Rows: 31128891
# Columns: 153
# root
#  |-- DEST: string (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- OP_UNIQUE_CARRIER: string (nullable = true)
#  |-- FL_DATE: date (nullable = true)
#  |-- prediction_utc: timestamp (nullable = true)
#  |-- origin_obs_utc: timestamp (nullable = true)
#  |-- asof_minutes: long (nullable = true)
#  |-- YEAR: integer (nullable = true)
#  |-- QUARTER: integer (nullable = true)
#  |-- DAY_OF_MONTH: integer (nullable = true)
#  |-- DAY_OF_WEEK: integer (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- CRS_ARR_TIME: integer (nullable = true)
#  |-- ORIGIN_AIRPORT_ID: integer (nullable = true)
#  |-- ORIGIN_STATE_ABR: string (nullable = true)
#  |-- DEST_AIRPORT_ID: integer (nullable = true)
#  |-- DEST_STATE_ABR: string (nullable = true)
#  |-- DISTANCE_high_corr: double (nullable = true)
#  |-- DISTANCE_GROUP_high_corr: integer (nullable = true)
#  |-- HourlyDryBulbTemperature: double (nullable = true)
#  |-- HourlyDewPointTemperature: double (nullable = true)
#  |-- HourlyWetBulbTemperature_high_corr: double (nullable = true)
#  |-- HourlyWindDirection: double (nullable = true)
#  |-- HourlyWindGustSpeed: double (nullable = true)
#  |-- HourlyVisibility: double (nullable = true)
#  |-- HourlyRelativeHumidity: double (nullable = true)
#  |-- HourlyStationPressure: double (nullable = true)
#  |-- HourlySeaLevelPressure_high_corr: double (nullable = true)
#  |-- HourlyAltimeterSetting: double (nullable = true)
#  |-- origin_airport_lat: double (nullable = true)
#  |-- origin_airport_lon: double (nullable = true)
#  |-- dest_airport_lat: double (nullable = true)
#  |-- dest_airport_lon: double (nullable = true)
#  |-- origin_station_dis: double (nullable = true)
#  |-- dest_station_dis: double (nullable = true)
#  |-- origin_type: string (nullable = true)
#  |-- DEP_DEL15: integer (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- departure_dayofweek: integer (nullable = true)
#  |-- is_weekend: integer (nullable = true)
#  |-- season: string (nullable = true)
#  |-- is_peak_month: integer (nullable = true)
#  |-- time_of_day_early_morning: integer (nullable = true)
#  |-- time_of_day_morning: integer (nullable = true)
#  |-- time_of_day_afternoon: integer (nullable = true)
#  |-- time_of_day_evening: integer (nullable = true)
#  |-- time_of_day_night: integer (nullable = true)
#  |-- rolling_origin_num_flights_24h_high_corr: long (nullable = true)
#  |-- rolling_origin_num_delays_24h: long (nullable = true)
#  |-- rolling_origin_delay_ratio_24h_high_corr: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_high_corr: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_carrier_high_corr: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_dayofweek: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_log: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_carrier_log: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_dayofweek_log: double (nullable = true)
#  |-- is_superbowl_week: integer (nullable = true)
#  |-- is_major_event: integer (nullable = true)
#  |-- weather_severity_index_high_corr: double (nullable = true)
#  |-- distance_medium: integer (nullable = true)
#  |-- distance_long: integer (nullable = true)
#  |-- distance_very_long: integer (nullable = true)
#  |-- weather_condition_category: string (nullable = true)
#  |-- is_airport_maintenance: integer (nullable = true)
#  |-- is_natural_disaster: integer (nullable = true)
#  |-- airline_reputation_score: integer (nullable = true)
#  |-- airline_reputation_category: string (nullable = true)
#  |-- airport_traffic_density: double (nullable = true)
#  |-- carrier_flight_count: long (nullable = true)
#  |-- weather_obs_lag_hours: double (nullable = true)
#  |-- log_distance: double (nullable = true)
#  |-- is_rainy: integer (nullable = true)
#  |-- prev_flight_dep_del15: double (nullable = true)
#  |-- prev_flight_crs_elapsed_time: double (nullable = true)
#  |-- hours_since_prev_flight: double (nullable = true)
#  |-- is_first_flight_of_aircraft: integer (nullable = true)
#  |-- turnaround_category: string (nullable = true)
#  |-- is_holiday_month: integer (nullable = true)
#  |-- num_airport_wide_delays: long (nullable = true)
#  |-- oncoming_flights: long (nullable = true)
#  |-- day_hour_interaction: string (nullable = true)
#  |-- prior_day_delay_rate: double (nullable = true)
#  |-- prior_flights_today: long (nullable = true)
#  |-- same_day_prior_delay_percentage: double (nullable = true)
#  |-- time_based_congestion_ratio: double (nullable = true)
#  |-- sky_condition_parsed: string (nullable = true)
#  |-- temp_humidity_interaction_high_corr: double (nullable = true)
#  |-- rapid_weather_change: integer (nullable = true)
#  |-- temp_anomaly: double (nullable = true)
#  |-- precip_anomaly_high_corr: double (nullable = true)
#  |-- dep_time_sin: double (nullable = true)
#  |-- dep_time_cos: double (nullable = true)
#  |-- arr_time_sin: double (nullable = true)
#  |-- arr_time_cos: double (nullable = true)
#  |-- day_of_week_sin: double (nullable = true)
#  |-- day_of_week_cos: double (nullable = true)
#  |-- month_sin: double (nullable = true)
#  |-- month_cos: double (nullable = true)
#  |-- wind_direction_sin: double (nullable = true)
#  |-- wind_direction_cos: double (nullable = true)
#  |-- extreme_precipitation: integer (nullable = true)
#  |-- extreme_wind: integer (nullable = true)
#  |-- extreme_temperature: integer (nullable = true)
#  |-- origin_degree_centrality: double (nullable = true)
#  |-- dest_degree_centrality_high_corr: double (nullable = true)
#  |-- origin_pagerank_high_corr: double (nullable = true)
#  |-- dest_pagerank_high_corr: double (nullable = true)
#  |-- origin_betweenness_high_corr: double (nullable = true)
#  |-- dest_betweenness: double (nullable = true)
#  |-- dest_delay_rate_today: double (nullable = true)
#  |-- delay_propagation_score: double (nullable = true)
#  |-- network_delay_cascade: integer (nullable = true)
#  |-- days_since_epoch: integer (nullable = true)
#  |-- origin_1yr_delay_rate: double (nullable = true)
#  |-- dest_1yr_delay_rate: double (nullable = true)
#  |-- rolling_30day_volume: long (nullable = true)
#  |-- days_since_last_delay_route: integer (nullable = true)
#  |-- days_since_carrier_last_delay_at_origin: integer (nullable = true)
#  |-- route_delays_30d: long (nullable = true)
#  |-- route_delay_rate_30d: double (nullable = true)
#  |-- carrier_delays_at_origin_30d: long (nullable = true)
#  |-- peak_hour_x_traffic: double (nullable = true)
#  |-- weekend_x_route_volume: long (nullable = true)
#  |-- weather_x_airport_delays: double (nullable = true)
#  |-- temp_x_holiday: double (nullable = true)
#  |-- route_delay_rate_x_peak_hour: double (nullable = true)
#  |-- rolling_delay_rate_squared_high_corr: double (nullable = true)
#  |-- log_distance_squared_high_corr: double (nullable = true)
#  |-- traffic_density_squared_high_corr: double (nullable = true)
#  |-- carrier_encoded_x_hour: double (nullable = true)
#  |-- origin_encoded_x_weather: double (nullable = true)
#  |-- origin_encoded_x_visibility: double (nullable = true)
#  |-- origin_encoded_x_precipitation: double (nullable = true)
#  |-- origin_encoded_x_wind: double (nullable = true)
#  |-- origin_x_dest_encoded: double (nullable = true)
#  |-- carrier_x_origin_encoded: double (nullable = true)
#  |-- carrier_x_dest_encoded: double (nullable = true)
#  |-- rf_prob_delay: double (nullable = true)
#  |-- rf_prob_delay_binned: integer (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_carrier_weighted: double (nullable = true)
#  |-- dep_delay15_24h_rolling_avg_by_origin_weighted: double (nullable = true)
#  |-- DEST_indexed: double (nullable = true)
#  |-- ORIGIN_indexed: double (nullable = true)
#  |-- OP_UNIQUE_CARRIER_indexed: double (nullable = true)
#  |-- ORIGIN_STATE_ABR_indexed: double (nullable = true)
#  |-- DEST_STATE_ABR_indexed: double (nullable = true)
#  |-- origin_type_indexed: double (nullable = true)
#  |-- season_indexed: double (nullable = true)
#  |-- weather_condition_category_indexed: double (nullable = true)
#  |-- airline_reputation_category_indexed: double (nullable = true)
#  |-- turnaround_category_indexed: double (nullable = true)
#  |-- day_hour_interaction_indexed: double (nullable = true)
#  |-- sky_condition_parsed_indexed: double (nullable = true)

# %%
from pyspark.sql import functions as F

GROUP_PATH = "dbfs:/student-groups/Group_4_4"
path_cp5_5y = f"{GROUP_PATH}/checkpoint_5_final_clean_2015-2019.parquet"

df = spark.read.parquet(path_cp5_5y)

print("Initial columns:", len(df.columns))

# 1) Drop all high-correlation helper features
cols_high_corr = [c for c in df.columns if c.endswith("_high_corr")]
print("Dropping _high_corr columns:", len(cols_high_corr))

# 2) Drop zero / near-zero importance features from Phase 2 analysis
zero_low_importance = [
    # simple flags that showed zero importance
    "is_peak_month",
    "extreme_wind",
    "is_weekend",
    "is_holiday_month",
    "rapid_weather_change",
    "extreme_temperature",
    "low_visibility",
    "QUARTER",
    "wind_direction_sin",
    "wind_direction_cos",
    "is_rainy",
    "extreme_precipitation",
    "time_of_day_morning",
    "departure_month",
    "is_first_flight_of_aircraft",
    "is_business_hours",
    "weather_obs_lag_hours",
    "time_of_day_evening",
    "YEAR",
    "time_of_day_night",
    "time_of_day_early_morning",
    "departure_dayofweek",
    "time_of_day_afternoon",
    "month_cos",
    "distance_long",
    "distance_medium",
]

# keep only the ones that actually exist in this dataframe
zero_low_importance = [c for c in zero_low_importance if c in df.columns]
print("Dropping zero/low-importance columns:", len(zero_low_importance))

# 3) Apply drops
df = df.drop(*cols_high_corr).drop(*zero_low_importance)

print("Columns after feature refinement:", len(df.columns))
# Out:
# Initial columns: 153
# Dropping _high_corr columns: 18
# Dropping zero/low-importance columns: 23
# Columns after feature refinement: 112

# %%
# Save refined feature set for Phase 3 modeling
out_path_refined = f"{GROUP_PATH}/checkpoint_5_final_clean_2015-2019_refined.parquet"

df.write.mode("overwrite").parquet(out_path_refined)
print("Saved refined 5Y features to:", out_path_refined)
# Out:
# Saved refined 5Y features to: dbfs:/student-groups/Group_4_4/checkpoint_5_final_clean_2015-2019_refined.parquet
